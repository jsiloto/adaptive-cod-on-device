# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv("results_dynamic_bitrate_s3.csv", header=None, delimiter=" ")
# print(df)
print(df.iloc[:, 0])
configurable = np.array([ [1.0, 16.6], [2.0, 29.7], [3.0, 34.6], [4.0, 36.8]]).T

plt.plot(df.iloc[:, 1], df.iloc[:, 0]*100)
plt.scatter(configurable[0], configurable[1])
# Out:
# 0     0.163571
# 1     0.192271
# 2     0.220909
# 3     0.251496
# 4     0.267235
# 5     0.280328
# 6     0.301065
# 7     0.318948
# 8     0.330647
# 9     0.337307
# 10    0.347060
# 11    0.357933
# 12    0.364000
# Name: 0, dtype: float64

# %%
df = pd.read_csv("results_dynamic_bitrate_s4.csv", header=None, delimiter=" ")
a = np.polyfit(df.iloc[:, 1], df.iloc[:, 0]*100, deg=2)
print(a)
# Out:
# [-1.72244633 15.14758066  3.41913862]
